# %% [markdown]
# <a href="https://colab.research.google.com/github/LearnWithChocolache/Trial_CNN/blob/main/Copy_of_trial_1_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import imghdr
import os

# %%
data_dir = 'drive/MyDrive/Dataset'

# %%
os.listdir(data_dir)
# Out:
# ['non_covid', 'pos_covid']

# %%
img_exts = ['jpeg','jpg','png']

# %%
#every single pic in the file
os.listdir(os.path.join(data_dir,'non_covid'))
# Out:
# ['Non-Covid (790).png',
#  'Non-Covid (789).png',
#  'Non-Covid (788).png',
#  'Non-Covid (791).png',
#  'Non-Covid (783).png',
#  'Non-Covid (784).png',
#  'Non-Covid (785).png',
#  'Non-Covid (786).png',
#  'Non-Covid (787).png',
#  'Non-Covid (782).png',
#  'Non-Covid (100).png',
#  'Non-Covid (101).png',
#  'Non-Covid (10).png',
#  'Non-Covid (102).png',
#  'Non-Covid (1).png',
#  'Non-Covid (109).png',
#  'Non-Covid (117).png',
#  'Non-Covid (120).png',
#  'Non-Covid (108).png',
#  'Non-Covid (119).png',
#  'Non-Covid (105).png',
#  'Non-Covid (111).png',
#  'Non-Covid (112).png',
#  'Non-Covid (104).png',
#  'Non-Covid (12).png',
#  'Non-Covid (116).png',
#  'Non-Covid (113).png',
#  'Non-Covid (110).png',
#  'Non-Covid (115).png',
#  'Non-Covid (103).png',
#  'Non-Covid (106).png',
#  'Non-Covid (118).png',
#  'Non-Covid (11).png',
#  'Non-Covid (107).png',
#  'Non-Covid (114).png',
#  'Non-Covid (222).png',
#  'Non-Covid (29).png',
#  'Non-Covid (195).png',
# ...

# %%
#looping every folder in data_dir
for image_class in os.listdir(data_dir):
  #print seluruh image inside sub dir
  for image in os.listdir(os.path.join(data_dir, image_class)):
    pass
